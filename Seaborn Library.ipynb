# %%
import seaborn as sns
import numpy as np
import pandas as pd
import pandas.util.testing as tm

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# point plot : which having only single parameters
sns.distplot(iris['petal_length'])

# %%
#kde= line which shows the max point in the graph
sns.distplot(iris['petal_length'],kde=False)

# %%
sns.rugplot(iris['petal_length'])

# %%
# distribution plot : two methods 
# 1. by subplot 2.
sns.residplot(x='sepal_length',y='sepal_width',data=iris)

# %%
sns.residplot(x='sepal_length',y='sepal_width',data=iris,lowess=True) #lower distribution

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris)

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='kde')

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='hex',color='#4CB391')

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='reg')

# %%
# pair plot : pair plot shows you to total possible combination of plots 
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')  #  hue parameter determines which column in the data frame should be used for colour encoding.

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.pairplot(tips,hue='day')

# %%
x=sns.pairplot(tips,hue='day')
x.map_diag(sns.distplot)
x.map_upper(sns.kdeplot)
# Out:
# C:\Users\sachi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kernels.py:128: RuntimeWarning: divide by zero encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# C:\Users\sachi\Anaconda3\lib\site-packages\statsmodels\nonparametric\kernels.py:128: RuntimeWarning: invalid value encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# C:\Users\sachi\Anaconda3\lib\site-packages\statsmodels\nonparametric\_kernel_base.py:516: RuntimeWarning: invalid value encountered in true_divide
#   dens = Kval.prod(axis=1) / np.prod(bw[iscontinuous])
# C:\Users\sachi\Anaconda3\lib\site-packages\matplotlib\contour.py:1520: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\sachi\Anaconda3\lib\site-packages\matplotlib\contour.py:1521: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# ...

# %%
 # categorical plot
sns.countplot(x='day',data=tips) #contains only one parametes

# %%
sns.pointplot(x='total_bill',y='day',data=tips)

# %%
sns.factorplot(x='total_bill',y='day',data=tips,kind='bar')
# Out:
# C:\Users\sachi\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.swarmplot(x='total_bill',y='day',data=tips,hue='sex')

# %%
sns.swarmplot(x='total_bill',y='day',data=tips,hue='sex',palette='cool')

# %%
sns.stripplot(x='total_bill',y='day',data=tips,hue='sex',palette='cool')

# %%
# categorial plot type
# bar plot
sns.barplot(x='day',y='tip',data=tips)

# %%
# 2. box plot
sns.boxplot(x='day',y='tip',data=tips,hue='sex')

# %%
# 3. violin plot
sns.violinplot(x='day',y='tip',data=tips,hue='sex')

# %%
# matrix ploting
# two methods :- 1. Corr 2. pivot
tip2=tips.corr()

# %%
tip2
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
iris2=iris.corr()

# %%
iris2
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(tip2)

# %%
sns.heatmap(iris2)

# %%
sns.heatmap(iris2,annot=True,linewidth=10)
# here values are decreasing

# %%
sns.heatmap(iris2,annot=True,linewidth=10,cmap='coolwarm')

# %%
# draw matrix graph using pivot method 
tips2=tips.pivot_table(index='day',columns='tip',values='total_bill')

# %%
tips2
# Out:
# tip   1.00   1.01   1.10   1.17   1.25   1.32   1.36   1.44   1.45   1.47   \
# day
# Thur    NaN    NaN    NaN    NaN   8.51    NaN  18.64   7.56    NaN    NaN
# Fri    5.75    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Sat    7.64    NaN   12.9  32.83  10.29    NaN    NaN   7.74   9.55  10.77
# Sun     NaN  16.99    NaN    NaN    NaN   9.68    NaN    NaN    NaN    NaN
#
# tip   ...  5.65   5.85   5.92   6.00   6.50   6.70   6.73   7.58   9.00   \
# day   ...
# Thur  ...    NaN  24.71    NaN    NaN    NaN   34.3    NaN    NaN    NaN
# Fri   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Sat   ...    NaN    NaN  29.03    NaN  28.17    NaN  48.27  39.42  48.33
# Sun   ...  23.33    NaN    NaN   32.4  23.17    NaN    NaN    NaN    NaN
#
# tip   10.00
# day
# Thur    NaN
# Fri     NaN
# Sat   50.81
# Sun     NaN
#
# [4 rows x 123 columns]

# %%
sns.heatmap(tips2,lw=1,cmap='cool')

# %%
sns.heatmap(tips2,cmap='cool')

# %%
# convert the data and then use it 
# cluster map :
sns.clustermap(iris2,cmap='cool')

# %%
# %matplotlib inline

# %%
sns.countplot(x='smoker',data=tips)
sns.set_context('paper') # it is used to change layout
# paper is a drawback  in style exp : poster ,notebook etc.

# %%
sns.countplot(x='smoker',data=tips)
sns.despine() # it is used to remove border

# %%
sns.countplot(x='smoker',data=tips)
sns.set_style('darkgrid') # set_style is used to change the background and other changes in map

# %%
sns.countplot(x='smoker',data=tips)
sns.set_style('ticks')
